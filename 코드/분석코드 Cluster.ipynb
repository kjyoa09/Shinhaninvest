# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('RAA_Naver_많이본뉴스기사제목.csv')

# %% [markdown]
# ## 전처리
#     1. 괄호 및 괄호 안 문자 제거 ex <뉴욕증시>, [시황]
#     2. 특수문자 제거(한글,영어,- 제외하고 나머지)

# %%
import re
import konlpy

from konlpy.tag import Mecab

# %%
Bracket = re.compile(r'(\([^)]*\))|(\<[^)]*\>)|(\[[^)]*\])|(\{[^)]*\})')
df['pp뉴스제목명'] = df.뉴스제목명.map(lambda x:re.sub(Bracket,'',x))

# %%
def delword(x):
    word = re.compile(r'[^ㄱ-ㅎ| 가-힣|A-Z|a-z|\-]')
    x = word.sub(' ',x)
    x = re.sub(r' +',' ',x)
    return x

df['pp뉴스제목명'] = df.pp뉴스제목명.map(lambda x:delword(x))

# %%
df
# Out:
#              기준일자                                   뉴스제목명  \
# 0        20170101                 SK이노베이션 “올해 3조원 규모 투자”
# 1        20170101                  “상호금융 출자금은 원금 보장 안돼요”
# 2        20170101                경제부처 수장들 고사성어로 위기 극복 강조
# 3        20170101               비싼 ‘복어탕’이 대형마트에 등장한 이유는?
# 4        20170101              수출 2년 연속 감소…교역액 9천억달러 턱걸이
# ...           ...                                     ...
# 2752627  20210726  외벌이는 소득 8605만원, 맞벌이는 1억532만원까지 지원금 받는다
# 2752628  20210726                카카오그룹, 국내 5번째 시총 100조 전망
# 2752629  20210726        카카오뱅크 공모주 오늘부터 청약···1주라도 더 받으려면?
# 2752630  20210726            카카오뱅크 오늘부터 공모청약…1주라도 더 받으려면?
# 2752631  20210726                     탄소절감의 역설···알루미늄이 뜬다
#
#                                                      뉴스URL  \
# 0        https://finance.naver.com/news/news_read.nhn?a...
# 1        https://finance.naver.com/news/news_read.nhn?a...
# 2        https://finance.naver.com/news/news_read.nhn?a...
# 3        https://finance.naver.com/news/news_read.nhn?a...
# 4        https://finance.naver.com/news/news_read.nhn?a...
# ...                                                    ...
# 2752627  https://finance.naver.com/news/news_read.nhn?a...
# 2752628  https://finance.naver.com/news/news_read.nhn?a...
# 2752629  https://finance.naver.com/news/news_read.nhn?a...
# 2752630  https://finance.naver.com/news/news_read.nhn?a...
# 2752631  https://finance.naver.com/news/news_read.nhn?a...
#
#                                 pp뉴스제목명
# 0                  SK이노베이션 올해 조원 규모 투자
# 1                  상호금융 출자금은 원금 보장 안돼요
# 2              경제부처 수장들 고사성어로 위기 극복 강조
# 3               비싼 복어탕 이 대형마트에 등장한 이유는
# 4              수출 년 연속 감소 교역액 천억달러 턱걸이
# ...                                 ...
# 2752627  외벌이는 소득 만원 맞벌이는 억 만원까지 지원금 받는다
# 2752628             카카오그룹 국내 번째 시총 조 전망
# 2752629   카카오뱅크 공모주 오늘부터 청약 주라도 더 받으려면
# 2752630     카카오뱅크 오늘부터 공모청약 주라도 더 받으려면
# 2752631               탄소절감의 역설 알루미늄이 뜬다
#
# [2752632 rows x 4 columns]

# %% [markdown]
# ## Custom Pos
#     1. Mecab pos 문제점
#         a. 한개의 단어를 나눔 ex >> 카카오뱅크 : ('카카오', 'NNP'), ('뱅크', 'NNG')
#                                     SK이노베이션 : ('SK', 'SL'), ('이노베이션', 'NNG')
#
#            - Wanted : 명사 or 외국어 태그가 연속으로 이어질 때 NNP로 묶은 결과도 노출
#                ex >> SK이노베이션 >> ('SK이노베이션','NNP'), ('SK','SL'), ('이노베이션', 'NNG')
#                      카카오뱅크   >> ('카카오뱅크','NNP'), ('카카오', 'NNP'), ('뱅크', 'NNG')
#
#         b. 1개의 단어로 이루어져 있을 경우 해석이 애매함 ex >> 것, 수 ..
#             - Threshold(min_lenn) 기준으로 적으면 제외
#
#     2. 위의 처리를 하고 나온 결과물의 명사 수가 너무 적을 경우 뉴스 기사 제외

# %%
mecab = Mecab('C:/mecab/mecab-ko-dic')

# %%
def custompos(sent,min_len = 1):
    sents = sent.split(" ")
    tags = ['NNP','SL','NNG']
    result = []
    for se in sents:
        tagging = mecab.pos(se)
        if len(tagging) == 1:
            v,tg = tagging[0]
            if tg in tags and len(v) > min_len:
                result.append(v)
        else:
            tmp = ''
            flag = False
            for v,tg in tagging:
                if tmp == '':
                    if tg in tags and len(v) > min_len:
                        tmp = v
                        result.append(v)
                else:
                    if tg in tags and len(v) > min_len:
                        tmp += v
                        result.append(v)
                        flag = True
                    elif flag:
                        result.append(tmp)
                        tmp = ''
                        flag = False
            if flag:
                result.append(tmp)
    return result

# %%
min_count = 3
df['nouns'] = df.pp뉴스제목명.map(lambda x: ' '.join(custompos(x)))
df = df[df.nouns.apply(lambda x: True if len(x.split(' ')) > min_count  else False)].reset_index(drop = True)

# %%
df.groupby('기준일자').count().describe()
# Out:
#              뉴스제목명        뉴스URL      pp뉴스제목명        nouns
# count  1668.000000  1668.000000  1668.000000  1668.000000
# mean   1514.917866  1514.917866  1514.917866  1514.917866
# std     946.205353   946.205353   946.205353   946.205353
# min      16.000000    16.000000    16.000000    16.000000
# 25%     563.750000   563.750000   563.750000   563.750000
# 50%    1825.000000  1825.000000  1825.000000  1825.000000
# 75%    2272.750000  2272.750000  2272.750000  2272.750000
# max    4398.000000  4398.000000  4398.000000  4398.000000

# %% [markdown]
# ## 분석
#     1. 목표
#
#         하루 평균 1500건이 넘는 뉴스 중에서 비슷한 내용의 기사들을 그룹화하고 그중 가장 중심성이 높은 기사 한 건을 노출
#
#     2. 방법론 : Graph-based News Representation
#
#         a. 가정
#             - 많은 언론사들이 유사한 제목의 비슷한 기사를 보도한다면 해당 사건이나 이슈는 사회에 파급력이 클 가능성이 높다.
#
#         b. 방법
#             - Degree centrality(간선중심성) : 기사 그룹과 중심성 Index 가중치로 활용
#                 BFS를 활용한 기사간 연결확인 >> Threshold : 몇 개 이상의 단어가 겹쳐야 연결된 것인지
#
#             - Eigenvector centrality(고유벡터중심성)
#                 기사간 연결을 나타낸 행렬을 PCA >> First Eigenvctor만 활용
#
#     3. 적용
#         a. 날짜별로(yyyymmdd) 뉴스 기사 그룹, 간선중심성, 고유백터중심성 계산
#         b. 기사의 중심성 Index = 간선중심성 * 고유백터중심성

# %%
df = df[df.뉴스제목명.map(lambda x: True if ('[표]' not in x) and ('[사진]' not in x) else False)].reset_index(drop = True)

# %%
from collections import deque
from sklearn import decomposition
from tqdm import tqdm

def ftn(yyyymmdd,Threshold):
    tmp = df[df.기준일자 == yyyymmdd].loc[:,'nouns'].to_list()
    dic = {idx:set(x.split(" ")) for idx,x in enumerate(tmp)}
    Len = len(dic)
    
    v,pc = [[0] * Len for _ in range(Len)],[[0] * Len for _ in range(Len)]
    
    for st in range(Len):
        for en in range(st+1,Len):
            inter = dic[st].intersection(dic[en])
            v[st][en],v[en][st] = len(inter),len(inter)
            pc[st][en],pc[en][st] = 1,1
    
    group = [0] * Len
    
    group_cnt = 1
    for idx,g in enumerate(group):
        if g == 0:
            que = deque([idx])
            while que:
                ix = que.popleft()
                if group[ix] == 0:
                    group[ix] = group_cnt
                    que.extend([i for i,v in enumerate(v[ix]) if v >= Threshold])
            group_cnt += 1
    
    pca = decomposition.PCA(n_components=1)
    pca_result = pca.fit(pc)
    
    return group,pca_result.components_[0],np.sum(v,axis = 0)

# %%
group,components,cnt = [],[],[]
for ymd in tqdm(df.기준일자.drop_duplicates().to_list()):
    a,b,c = ftn(ymd,4)
    group.extend(a)
    components.extend(b)
    cnt.extend(c)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1668/1668 [45:43<00:00,  1.64s/it]

# %%
df['group'] = group
df['components'] = components
df['cnt'] = cnt

# %%
df['idx'] = df.apply(lambda x: abs(x['components']) * x['cnt'],axis = 1)

# %%
df
# Out:
#              기준일자                                   뉴스제목명  \
# 0        20170101             SK이노베이션, 공격 투자로 기업가치 혁신 나선다
# 1        20170101        김준 SK이노베이션 사장 "올해 3조 투자...채용 확대"
# 2        20170101    SK이노베이션, 3조원 투자 '공격 경영'…5년간 1200명 채용
# 3        20170101                   SK이노베이션, 새해 3조원 투자 선언
# 4        20170101                 SK이노베이션 “올해 3조원 규모 투자”
# ...           ...                                     ...
# 2481794  20210726  외벌이는 소득 8605만원, 맞벌이는 1억532만원까지 지원금 받는다
# 2481795  20210726                카카오그룹, 국내 5번째 시총 100조 전망
# 2481796  20210726            카카오뱅크 오늘부터 공모청약…1주라도 더 받으려면?
# 2481797  20210726        카카오뱅크 공모주 오늘부터 청약···1주라도 더 받으려면?
# 2481798  20210726                     탄소절감의 역설···알루미늄이 뜬다
#
#                                                      뉴스URL  \
# 0        https://finance.naver.com/news/news_read.nhn?a...
# 1        https://finance.naver.com/news/news_read.nhn?a...
# 2        https://finance.naver.com/news/news_read.nhn?a...
# 3        https://finance.naver.com/news/news_read.nhn?a...
# 4        https://finance.naver.com/news/news_read.nhn?a...
# ...                                                    ...
# 2481794  https://finance.naver.com/news/news_read.nhn?a...
# 2481795  https://finance.naver.com/news/news_read.nhn?a...
# 2481796  https://finance.naver.com/news/news_read.nhn?a...
# 2481797  https://finance.naver.com/news/news_read.nhn?a...
# 2481798  https://finance.naver.com/news/news_read.nhn?a...
#
#                                        pp뉴스제목명  \
# 0                   SK이노베이션 공격 투자로 기업가치 혁신 나선다
# 1                김준 SK이노베이션 사장 올해 3조 투자 채용 확대
# 2            SK이노베이션 3조원 투자 공격 경영 5년간 1200명 채용
# 3                         SK이노베이션 새해 3조원 투자 선언
# 4                        SK이노베이션 올해 3조원 규모 투자
# ...                                        ...
# 2481794  외벌이는 소득 8605만원 맞벌이는 1억532만원까지 지원금 받는다
# 2481795                카카오그룹 국내 5번째 시총 100조 전망
# 2481796           카카오뱅크 오늘부터 공모청약 1주라도 더 받으려면
# 2481797         카카오뱅크 공모주 오늘부터 청약 1주라도 더 받으려면
# 2481798                      탄소절감의 역설 알루미늄이 뜬다
#
#                                         nouns  group  components  cnt  \
# 0        SK 이노베이션 SK이노베이션 공격 투자 기업 가치 기업가치 혁신      1   -0.093580  122
# 1          김준 SK 이노베이션 SK이노베이션 사장 올해 투자 채용 확대      1    0.072543  139
# 2             SK 이노베이션 SK이노베이션 조원 투자 공격 경영 채용      1   -0.055493  100
# 3                SK 이노베이션 SK이노베이션 새해 조원 투자 선언      1    0.035322  149
# 4                SK 이노베이션 SK이노베이션 올해 조원 규모 투자      1   -0.044142  117
# ...                                       ...    ...         ...  ...
# 2481794                         외벌 소득 맞벌이 지원금     12    0.092987    0
# 2481795                    카카오 그룹 카카오그룹 국내 전망     13    0.114660    4
# 2481796            카카오 뱅크 카카오뱅크 오늘 공모 청약 공모청약     14    0.158005    7
# 2481797                카카오 뱅크 카카오뱅크 공모주 오늘 청약     14    0.136332    8
# 2481798                    탄소 절감 탄소절감 역설 알루미늄     15    0.179678    0
#
#                idx
# 0        11.416782
# 1        10.083527
# 2         5.549299
# 3         5.262949
# 4         5.164609
# ...            ...
# 2481794   0.000000
# 2481795   0.458639
# 2481796   1.106036
# 2481797   1.090660
# 2481798   0.000000
#
# [2481799 rows x 9 columns]

# %%
df = df.sort_values(['기준일자','group','idx'],ascending = [True,True,False]).reset_index(drop = True)

# %%
df.iloc[:,[0,3,1,2,4,5,6]].to_csv('분석.csv',
         index = False)

# %%
df
# Out:
#              기준일자                                 뉴스제목명  \
# 0        20170101           SK이노베이션, 공격 투자로 기업가치 혁신 나선다
# 1        20170101      김준 SK이노베이션 사장 "올해 3조 투자...채용 확대"
# 2        20170101  SK이노베이션, 3조원 투자 '공격 경영'…5년간 1200명 채용
# ...           ...                                   ...
# 2481796  20210726          카카오뱅크 오늘부터 공모청약…1주라도 더 받으려면?
# 2481797  20210726      카카오뱅크 공모주 오늘부터 청약···1주라도 더 받으려면?
# 2481798  20210726                   탄소절감의 역설···알루미늄이 뜬다
#
#                                         nouns  group  components  cnt  \
# 0        SK 이노베이션 SK이노베이션 공격 투자 기업 가치 기업가치 혁신      1   -0.093580  122
# 1          김준 SK 이노베이션 SK이노베이션 사장 올해 투자 채용 확대      1    0.072543  139
# 2             SK 이노베이션 SK이노베이션 조원 투자 공격 경영 채용      1   -0.055493  100
# ...                                       ...    ...         ...  ...
# 2481796            카카오 뱅크 카카오뱅크 오늘 공모 청약 공모청약     14    0.158005    7
# 2481797                카카오 뱅크 카카오뱅크 공모주 오늘 청약     14    0.136332    8
# 2481798                    탄소 절감 탄소절감 역설 알루미늄     15    0.179678    0
#
#                idx
# 0        11.416782
# 1        10.083527
# 2         5.549299
# ...            ...
# 2481796   1.106036
# 2481797   1.090660
# 2481798   0.000000
#
# [2481799 rows x 7 columns]

# %%
df = pd.read_csv('분석.csv')

# %%
df = pd.merge(df,
              df.loc[:,['기준일자','group','뉴스제목명']].groupby(['기준일자','group'],as_index= False).count().rename(columns = {
                  '뉴스제목명' : 'Group_count'
              }),
              on = ['기준일자','group'])

# %%
df
# Out:
#              기준일자  group                                   뉴스제목명  \
# 0        20170101      1             SK이노베이션, 공격 투자로 기업가치 혁신 나선다
# 1        20170101      1        김준 SK이노베이션 사장 "올해 3조 투자...채용 확대"
# 2        20170101      1    SK이노베이션, 3조원 투자 '공격 경영'…5년간 1200명 채용
# 3        20170101      1                   SK이노베이션, 새해 3조원 투자 선언
# 4        20170101      1                 SK이노베이션 “올해 3조원 규모 투자”
# ...           ...    ...                                     ...
# 2481794  20210726     12  외벌이는 소득 8605만원, 맞벌이는 1억532만원까지 지원금 받는다
# 2481795  20210726     13                카카오그룹, 국내 5번째 시총 100조 전망
# 2481796  20210726     14            카카오뱅크 오늘부터 공모청약…1주라도 더 받으려면?
# 2481797  20210726     14        카카오뱅크 공모주 오늘부터 청약···1주라도 더 받으려면?
# 2481798  20210726     15                     탄소절감의 역설···알루미늄이 뜬다
#
#                                         nouns  components  cnt        idx  \
# 0        SK 이노베이션 SK이노베이션 공격 투자 기업 가치 기업가치 혁신   -0.093580  122  11.416782
# 1          김준 SK 이노베이션 SK이노베이션 사장 올해 투자 채용 확대    0.072543  139  10.083527
# 2             SK 이노베이션 SK이노베이션 조원 투자 공격 경영 채용   -0.055493  100   5.549299
# 3                SK 이노베이션 SK이노베이션 새해 조원 투자 선언    0.035322  149   5.262949
# 4                SK 이노베이션 SK이노베이션 올해 조원 규모 투자   -0.044142  117   5.164609
# ...                                       ...         ...  ...        ...
# 2481794                         외벌 소득 맞벌이 지원금    0.092987    0   0.000000
# 2481795                    카카오 그룹 카카오그룹 국내 전망    0.114660    4   0.458639
# 2481796            카카오 뱅크 카카오뱅크 오늘 공모 청약 공모청약    0.158005    7   1.106036
# 2481797                카카오 뱅크 카카오뱅크 공모주 오늘 청약    0.136332    8   1.090660
# 2481798                    탄소 절감 탄소절감 역설 알루미늄    0.179678    0   0.000000
#
#          Group_count
# 0                 14
# 1                 14
# 2                 14
# 3                 14
# 4                 14
# ...              ...
# 2481794            1
# 2481795            1
# 2481796            2
# 2481797            2
# 2481798            1
#
# [2481799 rows x 8 columns]

# %%
df
# Out:
#              기준일자  group                                   뉴스제목명  \
# 0        20170101      1             SK이노베이션, 공격 투자로 기업가치 혁신 나선다
# 1        20170101      1        김준 SK이노베이션 사장 "올해 3조 투자...채용 확대"
# 2        20170101      1    SK이노베이션, 3조원 투자 '공격 경영'…5년간 1200명 채용
# 3        20170101      1                   SK이노베이션, 새해 3조원 투자 선언
# 4        20170101      1                 SK이노베이션 “올해 3조원 규모 투자”
# ...           ...    ...                                     ...
# 2481794  20210726     12  외벌이는 소득 8605만원, 맞벌이는 1억532만원까지 지원금 받는다
# 2481795  20210726     13                카카오그룹, 국내 5번째 시총 100조 전망
# 2481796  20210726     14            카카오뱅크 오늘부터 공모청약…1주라도 더 받으려면?
# 2481797  20210726     14        카카오뱅크 공모주 오늘부터 청약···1주라도 더 받으려면?
# 2481798  20210726     15                     탄소절감의 역설···알루미늄이 뜬다
#
#                                         nouns  components  cnt        idx  \
# 0        SK 이노베이션 SK이노베이션 공격 투자 기업 가치 기업가치 혁신   -0.093580  122  11.416782
# 1          김준 SK 이노베이션 SK이노베이션 사장 올해 투자 채용 확대    0.072543  139  10.083527
# 2             SK 이노베이션 SK이노베이션 조원 투자 공격 경영 채용   -0.055493  100   5.549299
# 3                SK 이노베이션 SK이노베이션 새해 조원 투자 선언    0.035322  149   5.262949
# 4                SK 이노베이션 SK이노베이션 올해 조원 규모 투자   -0.044142  117   5.164609
# ...                                       ...         ...  ...        ...
# 2481794                         외벌 소득 맞벌이 지원금    0.092987    0   0.000000
# 2481795                    카카오 그룹 카카오그룹 국내 전망    0.114660    4   0.458639
# 2481796            카카오 뱅크 카카오뱅크 오늘 공모 청약 공모청약    0.158005    7   1.106036
# 2481797                카카오 뱅크 카카오뱅크 공모주 오늘 청약    0.136332    8   1.090660
# 2481798                    탄소 절감 탄소절감 역설 알루미늄    0.179678    0   0.000000
#
#          Group_count
# 0                 14
# 1                 14
# 2                 14
# 3                 14
# 4                 14
# ...              ...
# 2481794            1
# 2481795            1
# 2481796            2
# 2481797            2
# 2481798            1
#
# [2481799 rows x 8 columns]

# %%
tmp = df.sort_values(['기준일자','Group_count','idx'],ascending=[True,False,False])

# %%
tmp
# Out:
#              기준일자  group                                    뉴스제목명  \
# 284      20170101    172  삼성, ‘플렉스워시’세탁기 ‘플렉스드라이’건조기 CES 2017서 공개
# 285      20170101    172          삼성, '플렉스워시'와 '플렉스드라이' 건조기 최초 공개
# 286      20170101    172                   삼성전자, '플렉스워시'·'플렉스드라이'
# 287      20170101    172            삼성, 복합세탁기·건조기 '플렉스워시·드라이' 선보여
# 288      20170101    172                삼성， CES서 업계 최초 종합세탁솔루션 공개
# ...           ...    ...                                      ...
# 2481788  20210726      6           bhc에 아웃백 넘기는 스카이레이크…엑시트 박차 가한다
# 2481790  20210726      8              네이버, 2분기 호실적 타고 시가총액 3위 굳히나
# 2481793  20210726     11              생활부터 취업까지, 열여덟 청년들 자립 돕기 온힘
# 2481794  20210726     12   외벌이는 소득 8605만원, 맞벌이는 1억532만원까지 지원금 받는다
# 2481798  20210726     15                      탄소절감의 역설···알루미늄이 뜬다
#
#                                                  nouns  components  cnt  \
# 284      삼성 플렉스 워시 플렉스워시 세탁기 플렉스 드라이 플렉스드라이 건조기 CES 공개    0.114012  118
# 285           삼성 플렉스 워시 플렉스워시 플렉스 드라이 플렉스드라이 건조기 최초 공개    0.068174  107
# 286                   삼성전자 플렉스 워시 플렉스워시 플렉스 드라이 플렉스드라이   -0.097737   72
# 287               삼성 복합 세탁기 복합세탁기 건조기 플렉스 워시 플렉스워시 드라이    0.067260   87
# 288                  삼성 CES 업계 최초 종합 세탁 솔루션 종합세탁솔루션 공개   -0.068531   84
# ...                                                ...         ...  ...
# 2481788                     bhc 아웃백 스카이 레이크 스카이레이크 엑시트    0.017133    0
# 2481790                                 네이버 분기 호실 시가총액    0.017133    0
# 2481793                                    생활 취업 청년 자립    0.071314    0
# 2481794                                  외벌 소득 맞벌이 지원금    0.092987    0
# 2481798                             탄소 절감 탄소절감 역설 알루미늄    0.179678    0
#
#                idx  Group_count
# 284      13.453365           21
# 285       7.294630           21
# 286       7.037044           21
# 287       5.851632           21
# 288       5.756579           21
# ...            ...          ...
# 2481788   0.000000            1
# 2481790   0.000000            1
# 2481793   0.000000            1
# 2481794   0.000000            1
# 2481798   0.000000            1
#
# [2481799 rows x 8 columns]

# %%
tmp = tmp.groupby(['기준일자','group']).head(1)

# %%
tmp.loc[:,['기준일자','뉴스제목명','idx','Group_count']].to_csv('Results.csv',
         index = False)

# %%
tmp.groupby('기준일자').head(15).loc[:,['기준일자','뉴스제목명']].to_csv('sample.csv',
         index = False)

# %%
tmp.groupby(['기준일자','group']).head(1).to_csv('sample.csv',
         index = False)

# %%
ttmp = tmp.groupby(['기준일자','group']).head(1)

# %%
ttmp = ttmp[ttmp.기준일자 == 20170707].loc[:,['기준일자','뉴스제목명','idx','Group_count','group']].head(15)
ttmp.index = range(1,16)
ttmp
# Out:
#         기준일자                                          뉴스제목명        idx  \
# 1   20170707              [특징주]삼성전자, 분기 사상 최대 실적에 발표에도 '약세'  45.316870
# 2   20170707               경찰, 대한항공 본사 압수수색…횡령·배임 혐의 수사(속보)  13.740401
# 3   20170707               에스디시스템, 파나마기업과 21억 규모 유지보수 계약 체결   8.785467
# 4   20170707           신한銀, 본부부서 조직 개편…현장 영업동력 강화 및 커뮤니티 지원  11.605676
# 5   20170707            GS, 당진에 LNG복합발전소 준공..국내 최대 민간발전사 우뚝   5.889676
# 6   20170707                         KD건설, 179억원 규모 유상증자 결정   3.603000
# 7   20170707              뉴욕증시 민간고용 부진 등에 약세…다우 0.74% 하락 마감  11.684119
# 8   20170707             한국씨티은행, 영업점 5곳 오늘 폐점‥이달중 35계 문닫아     5.386825
# 9   20170707                 금호타이어 채권단, 지난해 경영평가 D등급 확정(2보)   4.162548
# 10  20170707                        삼성자산운용, 유럽시장에 공모펀드 선보인다   6.579900
# 11  20170707          [특징주] 오리온, 분할 재상장 첫날 약세…오리온홀딩스는 소폭 상승   5.806080
# 12  20170707  "셀트리온, 주력 제품 실적과 신규 라인 북미진출 모멘텀…목표가↑"-현대차투자증권  10.564809
# 13  20170707            "기아차, 2분기 실적 기대치 밑돌 듯…하반기 개선 예상"-하나  23.045949
# 14  20170707                  비씨카드, KT와 국가 주도 ‘빅데이터 사업’에 참여   5.593323
# 15  20170707                      [특징주]대한항공, 본사 압수수색 소식에 하락  10.559822
#
#     Group_count  group
# 1           226     27
# 2            48      9
# 3            32    162
# 4            22    104
# 5            18      4
# 6            18     65
# 7            16     78
# 8            16     20
# 9            15     34
# 10           14     85
# 11           13    221
# 12           12     48
# 13           11     35
# 14           11    130
# 15           10    219

# %%
pd.set_option("display.max_rows",300)

# %%
df[(df.기준일자 == 20170707) & (df.group == 27)].loc[:,['기준일자','group','뉴스제목명']]
# Out:
#             기준일자  group                                              뉴스제목명
# 285557  20170707     27                  [특징주]삼성전자, 분기 사상 최대 실적에 발표에도 '약세'
# 285558  20170707     27             삼성전자 사상 최대 영업이익, 모바일 역할 톡톡…갤럭시노트FE 기대↑
# 285559  20170707     27       [빅데이터MSI]7일 빅데이터 '핫 키워드'…실적·시장·서비스·영업이익·스마트폰
# 285560  20170707     27              LG전자, 'G6' 부진으로 2분기 영업이익 6641억원밖에 못 내
# 285561  20170707     27                LG전자, 2분기 영업이익 6641억원…전년동기보다 13.6%↑
# 285562  20170707     27                    LG전자 2분기 영업이익 6641억원…기대치 하회(상보)
# 285563  20170707     27                                  삼성전자 2분기 영업익 14조원
# 285564  20170707     27                        영업익 14조… 삼성전자, 애플 넘어 글로벌 1위
# 285565  20170707     27                   삼성전자, 반도체 '날다'…2분기 영업익 8조 추정(상보)
# 285566  20170707     27                    삼성전자 2분기 영업이익률 23.3%…사상 최고치(속보)
# 285567  20170707     27                   삼성전자, 2분기 매출 60조…전년比 17.79%↑(2보)
# 285568  20170707     27                삼성전자 분기 영업이익 14조, 글로벌 시총1위 애플도 '추월'
# 285569  20170707     27                        삼성전자 2분기 영업이익 14조···사상최대 실적
# 285570  20170707     27                    LG전자 2분기 영업이익 6641억원…기대치 하회(3보)
# 285571  20170707     27            [이데일리N] 삼성전자 2분기 영업익 14조원 '세계최고 수익기업' 外
# 285572  20170707     27                   삼성전자 2분기 영업이익 14조…"어닝서프라이즈 "(상보)
# 285573  20170707     27               LG전자, 가전·TV 2분기 실적 견인…스마트폰 흑자전환은 미뤄져
# 285574  20170707     27                  총수부재 삼성전자, 어닝서프라이즈 실적에도 '위기감' 고조
# 285575  20170707     27                               삼성전자 올해 2분기 영업익 14조원
# 285576  20170707     27                     '총수없는' 삼성전자, 사상최고 실적에도 "미래 불안"
# 285577  20170707     27        삼성전자, 2분기 잠정 영업이익 14조원…전년 동기 대비 71.99%↑(1보)
# 285578  20170707     27         LG전자, 2분기 매출 14.5조·영업익 6641억…"기대치 밑돌아"(종합)
# 285579  20170707     27                      [마감시황]코스피, 삼성전자 사상 최대 실적에도 하락
# 285580  20170707     27            삼성전자, 글로벌IT 영업익 1위… 영업이익률 ‘魔의 20% 벽’ 깼다
# 285581  20170707     27                 [클릭 e종목]뷰웍스, 2분기 실적 기대치 하회 전망…목표가↓
# 285582  20170707     27                    LG전자, 2분기 영업이익 6641억원…전년比13.6%↑
# 285583  20170707     27                [경향포토]삼성전자 "2분기 매출 60조원, 영업이익 14조원"
# 285584  20170707     27                             LG전자, 2분기 영업이익 6,641억원
# 285585  20170707     27                       [포토]삼성전자, 2017년 2분기 영업익 14조원
# 285586  20170707     27                 LG전자, 2분기 매출 14.5조…영업이익 6641억원(상보)
# 285587  20170707     27               삼성전자, 2분기 영업이익 14조원 추정···전년 比 72% 늘어
# 285588  20170707     27                           LG전자, 2Q 영업이익 6641억원(1보)
# 285589  20170707     27               [마감시황]삼성전자 사상최대 실적에도… 코스피 2370선까지 밀려
# 285590  20170707     27                삼성전자, 2Q 매출 60조 ·영업익 14조 ..사상최대(1보)
# 285591  20170707     27                      LG전자, 2Q 영업익 6641억…전년비 13.6%↑
# 285592  20170707     27                            삼성전자 2분기 영업익 14조원 ‘신기록’
# 285593  20170707     27           삼성전자, 2분기 영업이익 14조 원 '역대 최대'...애플도 앞지를 듯
# 285594  20170707     27        삼성전자 2Q 영업익 14조원 '어닝 서프라이즈'¨72% 늘어난 사상 최고실적
# 285595  20170707     27               LG전자, 2분기 영업이익 6,641억원···전년 比 14% 늘어
# 285596  20170707     27                       삼성전자, 2분기 영업이익 14조…사상 최대(3보)
# 285597  20170707     27                          [포토]삼성전자, 2분기 '영업이익 14조원'
# 285598  20170707     27               삼성전자, 2분기 매출 60조·영업익 14조…'사상 최대'(상보)
# 285599  20170707     27       LG전자, 2분기 잠정 매출 14조5552억원…전년 동기 대비 3.9%↑(2보)
# 285600  20170707     27                  [오늘의 종목] LG상사, 2·4분기 실적 기대치 하회 전망
# 285601  20170707     27           [종합]LG전자, 2분기 매출 전년 대비 소폭 증가···"가전으로 선방"
# 285602  20170707     27             LG전자 상반기 영업익 1조5856억…지난해 실적 이미 넘겨 (종합)
# 285603  20170707     27                         2분기 영업익 14조… 삼성전자 사상 최대 실적
# 285604  20170707     27                          코스피, 삼성전자 서프라이즈 실적에도 '하락'
# 285605  20170707     27      [2보] 삼성전자 2분기 잠정 실적, 전년 대비 매출 17%ㆍ영업이익 71% 증가
# 285606  20170707     27                             일부 증권사 3분기 영업이익 15조 예상
# 285607  20170707     27         '반도체의 힘'..매출 60조·영업익 14조, 최대 실적 낸 삼성전자(상보)
# 285608  20170707     27                   삼성전자 분기 영업이익 14조..과감한 미래투자 '결실'
# 285609  20170707     27                      삼성전자 '애플과 인텔 제치고 글로벌 IT 세계1위'
# 285610  20170707     27                          삼성전자 2분기 영업이익 14조 원…사상 최대
# 285611  20170707     27                   [특징주]삼성전자, 사상 최대 분기 실적 달성에도 '약세'
# 285612  20170707     27                      삼성전자, 2분기 영업이익 14조 원…애플 앞지르나?
# 285613  20170707     27             삼성전자 2분기 영업익 14조원 ‘신기록’...내부선 “지금이 위기”
# 285614  20170707     27                            사상최고 이익 낸 삼성전자가 불안한 이유는
# 285615  20170707     27                               삼성전자, 오늘 2분기 잠정실적 발표
# 285616  20170707     27                 삼성전자 반도체 세계 최강, 영업이익 7.9조…스마트폰도 부활
# 285617  20170707     27          삼성전자, 2분기 잠정 매출 60조원…전년 동기 대비 17.79%↑(2보)
# 285618  20170707     27                            코스피, 삼성전자 최대실적 불구 하락 마감
# 285619  20170707     27                          LG전자, 2분기 영업이익 6641억원(2보)
# 285620  20170707     27                삼성전자 2분기 매출 60조 영업이익 14조…‘사상 최대’ 실적
# 285621  20170707     27                      삼성전자, ‘실적발표일의 저주’ 어게인?…주가 하락세
# 285622  20170707     27                  코스피, 삼성電 '깜짝실적' 불구 하락... 외인 '팔자'
# 285623  20170707     27                 삼성전자, 2분기 영업이익 14조…전년比 71.99%↑(1보)
# 285624  20170707     27               삼성전자 DP부문, 영업이익 1.5조↑…LCD·OLED 모두 호조
# 285625  20170707     27                           2분기 영업이익 14조…반도체 ‘1등 공신’
# 285626  20170707     27           삼성전자, 2분기 매출 60조·영업익 14조…"예상대로 최대실적"(종합)
# 285627  20170707     27                          "삼성전자, 깜짝실적…하반기 실적 확대"-NH
# 285628  20170707     27                삼성전자 2분기 매출 60조원…분기매출 60조원 첫 돌파(속보)
# 285629  20170707     27                          삼성전자 2분기 영업이익 14조원 '사상최대'
# 285630  20170707     27                           LG전자 2분기 실적, 영업이익 13% 늘어
# 285631  20170707     27             삼성전자, 2분기 영업익 13조 전망…사상 첫 인텔·애플 넘어설 듯
# 285632  20170707     27                      삼성전자, 애플·인텔 뛰어넘었다…2분기 '깜짝 실적'
# 285633  20170707     27                           삼성전자, 애플·인텔 제쳤다…세계 1위 등극
# 285634  20170707     27                         [ET투자뉴스]LG전자, 17년2분기 실적 발표
# 285635  20170707     27  [삼성전자 2분기 영업익 14兆 '사상 최고'] 삼성은 웃는데.. LG전자 실적 예...
# 285636  20170707     27                 `14조` 삼성전자, 2분기 세계 시총 1위 애플 실적 꺾는다
# 285637  20170707     27                 LG전자 2분기 영업익 6641억원···스마트폰 적자 지속된듯
# 285638  20170707     27       삼성전자, 사상최대 실적 불구…“SK가 부럽다” 총수 부재 경영공백 장기화 우려
# 285639  20170707     27                     삼성전자 역대최고 실적 달성하며 글로벌 IT 1위 도약
# 285640  20170707     27           LG전자, 2분기 영업이익 6641억원, 전기대비 27.9% 감소(종합)
# 285641  20170707     27                      삼성전자, 애플 제쳤다…2분기 영업익 14조 사상최대
# 285642  20170707     27                  [특징주]삼성전자, 2Q 사상최대 영업이익 발표에도 '약세'
# 285643  20170707     27             LG전자, 2Q 영업익 6641억원…가전 '웃고' 스마트폰 '부진'
# 285644  20170707     27                        삼성전자, 사상 최대 실적에도 장시작 직후 하락세
# 285645  20170707     27               삼성전자, 올 2Q 매출 60조원 사상 최대…전년比 17.79%↑
# 285646  20170707     27                     [속보] 삼성전자 2분기 영업이익 14조...사상 최대
# 285647  20170707     27                     삼성전자 또 '깜짝' 실적…매출 60조ㆍ영업이익 14조
# 285648  20170707     27                     삼성전자, 2분기 실적 사상최고치…‘갤럭시S8’이 효자
# 285649  20170707     27                삼성전자 사상 최대 실적…반도체가 견인, 세계 최고 제조업 수익
# 285650  20170707     27                         [특징주] 삼성전자 2분기 '깜짝실적'에도 하락
# 285651  20170707     27                   [특징주] 삼성전자, 분기사상 최대실적에도 약세…외인 매도
# 285652  20170707     27                    삼성전자 2분기 영업익 14조원…세계최고 수익기업(종합)
# 285653  20170707     27             "믿을건 '냉·세·에' 가전 삼총사"…LG전자, 스마트폰은 연속 적자
# 285654  20170707     27                         코스피, 삼성전자 최대 실적에도 불구 하락 마감
# 285655  20170707     27                         삼성전자, 2Q 잠정 영업이익 14조…사상 최대
# 285656  20170707     27                    삼성전자, 갤럭시노트FE 출시...'배터리 오명' 씻는다
# 285657  20170707     27                실적에 춤추는 주가 전망...삼성전자 '웃고' LG전자 '울고'
# 285658  20170707     27                       LG전자 2분기 영업이익 6,641억원…13.6%↑
# 285659  20170707     27                            [라인뉴스] 삼성전자 사상 최대 실적 달성
# 285660  20170707     27                                   삼성전자, 역대 최고실적 달성
# 285661  20170707     27                        [특징주]LG전자, 2Q 실적 발표 앞두고 하락세
# 285662  20170707     27                         [ET투자뉴스]삼성전자, 17년2분기 실적 발표
# 285663  20170707     27                 [경제브리핑] 삼성전자, 애플·인텔 꺾고 글로벌 IT 왕좌 외
# 285664  20170707     27                        삼성전자 2Q 잠정영업이익률 23.3%…역대 최고
# 285665  20170707     27                       '역대급 실적' 삼성전자 3Q 영업익 15조 넘는다
# 285666  20170707     27                       ‘글로벌 괴물’ 삼성전자 2분기 영업익 14조 괴력
# 285667  20170707     27                       코스피, 美증시 약세에 하락 출발…2,380선 공방
# 285668  20170707     27               LG전자 2분기 영업이익 6641억원…전년比 13.6↑ %(1보)
# 285669  20170707     27               코스피, 외국인 매도세에 7.94포인트 하락한 2379.87 마감
# 285670  20170707     27                        [특징주]LG전자, 2Q 실적 발표에 4%대 하락
# 285671  20170707     27                          세계최고 수익기업 등극…삼성전자, 애플 제쳤다
# 285672  20170707     27                 삼성전자, 2분기 영업익 14조원…역대 분기 최고 실적(상보)
# 285673  20170707     27                         [오전시황]글로벌 증시 부진에 코스피 동반 하락
# 285674  20170707     27                   [특징주] 삼성전자, 어닝서프라이즈 발표… 출발은 '약세'
# 285675  20170707     27                         삼성전자 사상 최대 실적…세계 최고 제조업 수익
# 285676  20170707     27                         LG전자, 실적 발표 앞두고 장초반 주가 하락세
# 285677  20170707     27                                   삼성전자 2분기 이익 14조원
# 285678  20170707     27                   [경향포토]삼성전자 올 2분기 사상 최고 수준의 실적 달성
# 285679  20170707     27               코스피, 10거래일만에 2380 내줘…삼성電 '깜짝실적'에도 하락
# 285680  20170707     27                    [특징주]LG전자, 2분기 실적 시장 예상치 하회…4%↓
# 285681  20170707     27                       삼성전자 2분기 잠정영업이익률 23.3%…역대 최고
# 285682  20170707     27                     [특징주]삼성전자, 사상최대 실적에도 하락…너무 올랐나
# 285683  20170707     27                     "삼성전자, 하반기 반도체·디스플레이 중심 실적 확대"
# 285684  20170707     27                 [특징주] 삼성전자, 2분기 최대 실적 발표에도 '하락 출발'
# 285685  20170707     27                   삼성전자, 2Q 잠정 매출액 60조…전년동기比 17.8%↑
# 285686  20170707     27                         코스피, 삼성전자 최대 실적에도 2370선 후퇴
# 285687  20170707     27               [특징주]LG전자, 저평가 지적에도 2분기 실적 발표 앞두고 약세
# 285688  20170707     27                "LG상사, 2분기 실적 저점 찍고 하반기 살아날 것" - NH
# 285689  20170707     27                                 삼성전자, 매출 60조원 사상최대
# 285690  20170707     27                                      갤럭시노트FE 본격 출시
# 285691  20170707     27                 삼성전자, 4년 만에 분기 최대 영업이익…14조 원 깜짝 실적
# 285692  20170707     27         ‘40만대 한정’ 갤럭시노트FE ‘인기’, 품절 사태도…갤럭시노트8 출시는?
# 285693  20170707     27                         옥션, ‘갤럭시노트 FE’ 단독 할인 혜택 판매
# 285694  20170707     27               [2보]삼성전자, 2분기 잠정 매출 60조원…전년比 17.79%↑
# 285695  20170707     27                      LG전자, 2Q 영업익 6641억…전년比 13.6%↑
# 285696  20170707     27                              LG전자,2Q 매출 14.6조원(2보)
# 285697  20170707     27            삼성전자 2분기 영업익 14조원·매출액 60조원 '사상 최대' (3보)
# 285698  20170707     27                  LG전자, 상반기 영업익 1조5856억…작년 실적 이미 넘어
# 285699  20170707     27                       코스피, 삼성전자 사상최대 실적에도 2370선 후퇴
# 285700  20170707     27          삼성전자, 2017년 2분기 영업익 14조원…전년比 71.99%↑ (1보)
# 285701  20170707     27                    삼성전자, 2분기 실적 '사상 최대'...애플 추월할 듯
# 285702  20170707     27                        [특징주] LG전자, 2Q 실적 발표 앞두고 약세
# 285703  20170707     27                       한정수량으로 판매되는 '갤럭시노트 FE' 만나보세요
# 285704  20170707     27                 삼성전자·LG전자 동반 약세… 'IT 주도' 모멘텀 약해지나
# 285705  20170707     27                       삼성SDI 7분기만에 흑자전환 기대, 52주 신고가
# 285706  20170707     27                          삼성전자 2분기 영업이익 14조원…'사상최대'
# 285707  20170707     27                            2분기 영업益 14조… 삼성전자 ‘새역사’
# 285708  20170707     27                          [특징주]LG전자, 실적 발표 앞두고 '약세'
# 285709  20170707     27                 올 상반기 훨훨 난 LG전자, 지난해 연간 영업이익 벌써 돌파
# 285710  20170707     27                            삼성전자 '매출 60조, 영업이익 14조'
# 285711  20170707     27                 '총수없는' 삼성전자, 사상최고 실적에도 "미래 불안"(종합)
# 285712  20170707     27                              SKT, 삼성 갤럭시 노트 FE 출시
# 285713  20170707     27                         뷰웍스, 2Q 실적 컨센서스 하회…목표가↓-삼성
# 285714  20170707     27                       컨센서스 못미친 LG전자, G6·마케팅 비용에 발목
# 285715  20170707     27                      삼성전자 실적 새역사 썼다···2분기 영업이익 14조
# 285716  20170707     27                       코스피 하락출발... 삼성전자 호실적 발표에도 약세
# 285717  20170707     27                                 삼성전자 '매출, 영업이익 급등'
# 285718  20170707     27                            또 다시 스마트폰 부진에 발목잡힌 LG전자
# 285719  20170707     27                           삼성전자 2분기 영업이익 14조, 사상 최대
# 285720  20170707     27             갤럭시노트FE 지원금, 저가요금제는 SKT  고가요금제는 KT가 최고
# 285721  20170707     27            [터치! Up&Down]삼성전자 오늘 실적발표, 어닝 서프라이즈 기대감
# 285722  20170707     27                          삼성전자 2분기 영업이익 14조…‘애플’ 추월
# 285723  20170707     27                              코스피, 삼성전자 '깜짝실적'에도 주춤
# 285724  20170707     27                   코스피, 美증시 약세에 하락 출발…2,380선 공방(종합)
# 285725  20170707     27                            삼성전자 최대 실적에도 하락 마감한 코스피
# 285726  20170707     27                               LG전자도 선전… 영업익 13.6%↑
# 285727  20170707     27               LG전자 2분기 매출 14조5552억원…젼년比 3.9%↑ (2보)
# 285728  20170707     27                  코스피, 외인·기관 '팔자'에 내리막…삼성電, 깜짝실적에도↓
# 285729  20170707     27                 세계를 놀라게 한 삼성전자..2분기 영업익 14조 '글로벌톱'
# 285730  20170707     27                     코스피, 글로벌 증시 하락·외국인 매도공세에 약세 흐름
# 285731  20170707     27         [마감시황]코스피, 삼성전자 '깜짝실적'에도 하락···2370선으로 내려앉아
# 285732  20170707     27                           코스피, 삼성전자 최대 실적 불구 하락 마감
# 285733  20170707     27                  반도체·디스플레이 쌍끌이… 삼성전자, 애플·인텔 실적 제쳤다
# 285734  20170707     27                              "LG상사, 2분기가 실적 저점"-NH
# 285735  20170707     27                                  ‘갤럭시 노트 FE’ 판매 개시
# 285736  20170707     27                  [마감]코스피, 삼성전자 好실적에도 하락…2370대로 ‘뚝’
# 285737  20170707     27                             최대실적에도 맘껏 못 웃는 삼성전자 왜?
# 285738  20170707     27                        [경향포토]삼성전자 분기 매출 60조원 시대 진입
# 285739  20170707     27                                 삼성전자 2분기 영업이익 14조원
# 285740  20170707     27                     ‘스마트폰 부진’ LG전자, 2분기 실적 전망치 밑돌아
# 285741  20170707     27                                글로벌 IT산업 왕좌 오른 삼성전자
# 285742  20170707     27                 반도체 '견인' 갤S8 '부활', 삼성전자 2Q 실적 '飛上'
# 285743  20170707     27                       [서울포토] 배터리 교체해 출시된 ‘갤럭시노트FE’
# 285744  20170707     27                 [4보]LG전자, 상반기 매출 29.2조원…전년比 6.8%↑
# 285745  20170707     27               ‘반도체의 힘’ 삼성전자 2분기 영업이익 14조···사상최대 실적
# 285746  20170707     27           [개장시황] 삼성전자 사상최고 실적에도···코스피 2370대까지 '뚝'
# 285747  20170707     27                       가전에 기댄 LG전자, 실적 기둥될 '원펀치' 필요
# 285748  20170707     27                         ‘갤럭시노트FE’, 옥션 단독할인 ‘올킬’ 뜬다
# 285749  20170707     27                  삼성전자, 2분기 영업이익 14조…'시간당 63억원 벌었다'
# 285750  20170707     27             LG전자, 2Q 매출 14.6조, 영업익 6600억원…예측치 '하회'
# 285751  20170707     27       LG전자, 2분기 잠정 영업이익 6641억원…전년 동기 대비 13.6%↑(1보)
# 285752  20170707     27          갤럭시노트 FE, 옥션에도 뜬다…'16% 즉시할인+4만원 중복할인쿠폰까지'
# 285753  20170707     27             [오전시황] 코스피, 글로벌 증시 부진ㆍ외인 매도세…2380선 보합권
# 285754  20170707     27                   [그래픽] 삼성전자 2분기 영업이익 14조원…어닝서프라이즈
# 285755  20170707     27                   [속보] 삼성전자 2분기 영업이익 14조 원…어닝서프라이즈
# 285756  20170707     27                     삼성전자 사상 최고 실적…애플·인텔 꺾는 새역사를 쓰다
# 285757  20170707     27                 삼성전자, 2Q 매출 60조·영업익 14조..'사상최대' 실적
# 285758  20170707     27                        옥션, 갤럭시노트 FE 예약 판매 기념 할인 나서
# 285759  20170707     27                             KT, 삼성전자 '갤럭시노트 FE' 판매
# 285760  20170707     27                    옥션, '갤럭시노트 FE' 1000대에 16% 할인 혜택
# 285761  20170707     27                       삼성, 애플-페북-인텔 글로벌 IT기업 모두 제꼈다
# 285762  20170707     27                     [특징주]삼성전자, 사상 최고 이익 발표...'약보합'
# 285763  20170707     27                 삼성전자, 올 2Q 영업益 14조원 사상 최대…전년比 72%↑
# 285764  20170707     27              삼성 `갤럭시노트FE` 출시…"고가 요금제, 20% 요금할인 유리"
# 285765  20170707     27                        삼성전자 어닝서프라이즈… 2분기 영업이익 14조원
# 285766  20170707     27                             사상 최대 실적에도 웃지 못하는 삼성전자
# 285767  20170707     27                        갤럭시노트FE, 6만원대 요금제 선택시 50만원대
# 285768  20170707     27                         갤럭시노트FE 초반 인기…일부 온라인 매장 품절
# 285769  20170707     27           [서울경제TV] 애플 제친 삼성전자 2분기 영업익 14조··· 역대 최대
# 285770  20170707     27                             삼성전자 2분기 '사상 최대 분기 실적'
# 285771  20170707     27                              사상최고 실적에도 웃을 수 없는 이재용
# 285772  20170707     27                     [Hot-Line] 삼성전자, 사상 최대 실적에도 약세
# 285773  20170707     27                   삼성전자 사상 최대 분기 매출, 영업이익에도 '위기' 왜?
# 285774  20170707     27          [경향포토]반도체 시장의 '슈퍼호황'...삼성전자 분기 매출 60조원 진입
# 285775  20170707     27                  LG전자, 2분기 매출액 14조5552억원…전년比 3.9%↑
# 285776  20170707     27                          옥션, `갤럭시노트 FE` 할인 프로모션 진행
# 285777  20170707     27                LG전자, 예상밑돈 2Q 성적…휴대폰에 '조성진 매직' 언제쯤?
# 285778  20170707     27                  코스피, 외국인 매도공세에 0.33%↓… 2379.87 마감
# 285779  20170707     27                   삼성전자, 반도체 힘입어 2분기 영업이익 14조…사상 최고
# 285780  20170707     27                             ‘갤럭시노트 FE’, 옥션 ‘올킬’ 뜬다
# 285781  20170707     27                   스마트폰 마케팅비 지출에…시장 기대치 밑돈 LG전자(종합)
# 285782  20170707     27                        삼성전자 2Q 디스플레이 영업이익 사상 최대 추정

# %%
df[(df.기준일자 == 20170707) & (df.group == 219)].loc[:,['기준일자','group','뉴스제목명']].head(3)
# Out:
#             기준일자  group                             뉴스제목명
# 286239  20170707    219         [특징주]대한항공, 본사 압수수색 소식에 하락
# 286240  20170707    219  [특징주] 대한항공 압수수색에 한진그룹株 동반 하락(종합)
# 286241  20170707    219     [특징주]대한항공, 경찰 압수수색 소식에 하락세 전환

# %%
tmp = df[(df.기준일자 == 20170707) & (df.group == 9)].loc[:,['기준일자','뉴스제목명']].reset_index(drop = True)

# %%
tmp.index = range(1,49)

# %%
tmp
# Out:
#         기준일자                               뉴스제목명
# 1   20170707    경찰, 대한항공 본사 압수수색…횡령·배임 혐의 수사(속보)
# 2   20170707  경찰, 대한항공 압수수색…회장 자택공사 관련 비리 혐의(종합)
# 3   20170707       경찰, 대한항공 본사 압수수색…횡령ㆍ배임 수사(속보)
# ..       ...                                 ...
# 46  20170707   대한항공 "경찰 수사 최대한 협조···자체 진상조사도 진행"
# 47  20170707                     경찰,대한항공 본사 압수수색
# 48  20170707       [종합]경찰, 대한항공 본사 압수수색···배임 혐의
#
# [48 rows x 2 columns]
